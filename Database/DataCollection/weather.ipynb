# %%
import pandas as pd

url = 'http://www.weather.com.cn/textFC/hb.shtml'
pd.read_html(url, header=1, index_col=[0, 1])[0]
# Out:
#           天气现象 风向风力 最高气温 天气现象.1    风向风力.1  最低气温 Unnamed: 8
# 省/直辖市 城市
# 北京    北京     -  - -    -     多云  西北风 3-4级    -1         详情
#       海淀     -  - -    -     多云  西北风 3-4级    -1         详情
#       朝阳     -  - -    -     多云   西北风 <3级     0         详情
#       顺义     -  - -    -     多云   西北风 <3级    -2         详情
#       怀柔     -  - -    -     多云   西北风 <3级    -3         详情
#       通州     -  - -    -     多云   西北风 <3级    -2         详情
#       昌平     -  - -    -     多云   西北风 <3级     0         详情
#       延庆     -  - -    -     多云    西风 <3级    -5         详情
#       丰台     -  - -    -     多云  西北风 3-4级    -1         详情
#       石景山    -  - -    -     多云  西北风 3-4级    -1         详情
#       大兴     -  - -    -     多云  西北风 3-4级    -2         详情
#       房山     -  - -    -     多云  西北风 3-4级    -2         详情
#       密云     -  - -    -     多云   东北风 <3级    -5         详情
#       门头沟    -  - -    -     多云  西北风 3-4级     0         详情
#       平谷     -  - -    -     多云   西北风 <3级    -5         详情
#       东城     -  - -    -     多云   西北风 <3级     0         详情
#       西城     -  - -    -     多云  西北风 3-4级    -1         详情

# %%
url = 'https://fund.eastmoney.com/fund.html'
pd.read_html(url)[2]
# Out:
#      关注  比较   序号   基金代码                      基金简称 2023-12-05          \
#      关注  比较   序号   基金代码                      基金简称       单位净值    累计净值
# 0   NaN NaN    1  17519        汇添富北证50成份指数A估值图基金吧     1.0122  1.0122
# 1   NaN NaN    2  17520        汇添富北证50成份指数C估值图基金吧     1.0085  1.0085
# 2   NaN NaN    3  17524       南方北证50成份指数发起C估值图基金吧     0.9882  0.9882
# 3   NaN NaN    4  17512         广发北证50成份指数A估值图基金吧     1.0541  1.0541
# 4   NaN NaN    5  17523       南方北证50成份指数发起A估值图基金吧     0.9910  0.9910
# ..   ..  ..  ...    ...                       ...        ...     ...
# 195 NaN NaN  196   8570             中航瑞智纯债C估值图基金吧     1.0272  1.0272
# 196 NaN NaN  197  18266  富国中债7-10年政策性金融债...估值图基金吧     1.0271  1.0271
# 197 NaN NaN  198  19596  富国中债7-10年政策性金融债...估值图基金吧     1.0271  1.0271
# 198 NaN NaN  199   1516            大成安汇金融债E估值图基金吧     1.0221  1.1129
# 199 NaN NaN  200   6177             中信保诚稳达A估值图基金吧     1.0216  1.2082
#
#     2023-12-04            日增长值   日增长率 申购状态 赎回状态    手续费
#           单位净值    累计净值    日增长值   日增长率 申购状态 赎回状态    手续费
# 0       0.9469  0.9469  0.0653  6.90%   开放   开放  0.10%
# 1       0.9434  0.9434  0.0651  6.90%   开放   开放  0.00%
# 2       0.9244  0.9244  0.0638  6.90%   开放   开放  0.00%
# 3       0.9862  0.9862  0.0679  6.89%   开放   开放  0.12%
# 4       0.9271  0.9271  0.0639  6.89%   开放   开放  0.12%
# ..         ...     ...     ...    ...  ...  ...    ...
# 195     1.0268  1.0268  0.0004  0.04%   开放   开放  0.00%
# 196     1.0267  1.0267  0.0004  0.04%   开放   开放  0.05%
# 197     1.0267  1.0267  0.0004  0.04%   开放   开放    ---
# 198     1.0217  1.1125  0.0004  0.04%   开放   开放  0.00%
# 199     1.0212  1.2078  0.0004  0.04%  限大额   开放  0.08%
#
# [200 rows x 14 columns]

# %%
dick = 'fuck'
dick
# Out:
# 'fuck'

# %%
import cv2
img = cv2.imread(r'F:\VSCode Files\Web\Notes\Statics\Image\test.png')
img.shape
# Out:
# (440, 472, 3)
