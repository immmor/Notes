# %%
import pandas as pd

url = 'http://www.weather.com.cn/textFC/hb.shtml'
pd.read_html(url, header=1, index_col=[0, 1])[0]
# Out:
#           天气现象     风向风力  最高气温 天气现象.1   风向风力.1  最低气温 Unnamed: 8
# 省/直辖市 城市
# 北京    北京     晴  东北风 <3级    15      晴  西南风 <3级     0         详情
#       海淀     晴   北风 <3级    17      晴  西南风 <3级     0         详情
#       朝阳     晴   北风 <3级    16      晴  西南风 <3级     1         详情
#       顺义     晴   北风 <3级    15      晴  东南风 <3级     0         详情
#       怀柔     晴   东风 <3级    16      晴   北风 <3级    -1         详情
#       通州     晴   北风 <3级    15      晴   南风 <3级    -1         详情
#       昌平     晴   北风 <3级    17      晴  东北风 <3级     0         详情
#       延庆     晴  西南风 <3级    13      晴   北风 <3级    -3         详情
#       丰台     晴   北风 <3级    16      晴  西南风 <3级     0         详情
#       石景山    晴  东北风 <3级    17      晴  西南风 <3级     0         详情
#       大兴     晴  东北风 <3级    16      晴  西南风 <3级    -1         详情
#       房山     晴  西南风 <3级    16      晴  西南风 <3级    -1         详情
#       密云     晴  东北风 <3级    16      晴   东风 <3级    -1         详情
#       门头沟    晴   北风 <3级    17      晴  西南风 <3级     0         详情
#       平谷     晴   北风 <3级    15      晴  东北风 <3级    -3         详情
#       东城     晴   北风 <3级    16      晴  西南风 <3级     1         详情
#       西城     晴   北风 <3级    17      晴  西南风 <3级     0         详情

# %%
url = 'https://fund.eastmoney.com/fund.html'
pd.read_html(url)[2]
# Out:
#      关注  比较   序号   基金代码                 基金简称 2023-11-17         2023-11-16  \
#      关注  比较   序号   基金代码                 基金简称       单位净值    累计净值       单位净值
# 0   NaN NaN    1   6718    国融融盛龙头严选混合A估值图基金吧     1.2614  1.3114     1.1925
# 1   NaN NaN    2   6719    国融融盛龙头严选混合C估值图基金吧     1.2972  1.3472     1.2264
# 2   NaN NaN    3  18956    中航机遇领航混合发起A估值图基金吧     0.9393  0.9393     0.8928
# 3   NaN NaN    4  18957    中航机遇领航混合发起C估值图基金吧     0.9376  0.9376     0.8912
# 4   NaN NaN    5  15097   东财数字经济混合发起式C估值图基金吧     0.7829  0.7829     0.7567
# ..   ..  ..  ...    ...                  ...        ...     ...        ...
# 195 NaN NaN  196  11808      平安研究精选混合C估值图基金吧     0.9133  0.9133     0.8963
# 196 NaN NaN  197   4321  前海开源沪港深强国产业混合估值图基金吧     0.8617  0.8617     0.8456
# 197 NaN NaN  198  12542      金鹰产业升级混合C估值图基金吧     0.4764  0.4764     0.4675
# 198 NaN NaN  199  20026       国泰成长优选混合估值图基金吧     2.4800  3.0020     2.4340
# 199 NaN NaN  200   1801       汇添富达欣混合A估值图基金吧     1.7800  1.8350     1.7470
#
#                日增长值   日增长率 申购状态 赎回状态    手续费
#        累计净值    日增长值   日增长率 申购状态 赎回状态    手续费
# 0    1.2425  0.0689  5.78%   开放   开放  0.15%
# 1    1.2764  0.0708  5.77%   开放   开放  0.00%
# 2    0.8928  0.0465  5.21%   开放   开放  0.15%
# 3    0.8912  0.0464  5.21%   开放   开放  0.00%
# 4    0.7567  0.0262  3.46%   开放   开放  0.00%
# ..      ...     ...    ...  ...  ...    ...
# 195  0.8963  0.0170  1.90%   开放   开放  0.00%
# 196  0.8456  0.0161  1.90%   开放   开放  0.15%
# 197  0.4675  0.0089  1.90%   开放   开放  0.00%
# 198  2.9560  0.0460  1.89%   开放   开放  0.15%
# 199  1.8020  0.0330  1.89%   开放   开放  0.15%
#
# [200 rows x 14 columns]
