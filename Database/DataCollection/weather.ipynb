# %%
import pandas as pd

url = 'http://www.weather.com.cn/textFC/hb.shtml'
pd.read_html(url, header=1, index_col=[0, 1])[0]
# Out:
#           天气现象     风向风力  最高气温 天气现象.1   风向风力.1  最低气温 Unnamed: 8
# 省/直辖市 城市
# 北京    北京     晴   南风 <3级     0      晴   南风 <3级    -8         详情
#       海淀     晴   南风 <3级     1      晴   南风 <3级    -8         详情
#       朝阳     晴   南风 <3级     1      晴   南风 <3级    -8         详情
#       顺义     晴   南风 <3级     0      晴  东南风 <3级    -8         详情
#       怀柔     晴   南风 <3级     0      晴   北风 <3级   -10         详情
#       通州     晴   南风 <3级     0      晴  东南风 <3级   -10         详情
#       昌平     晴  东南风 <3级     1      晴  东北风 <3级    -8         详情
#       延庆     晴  西南风 <3级    -3      晴  东北风 <3级   -13         详情
#       丰台     晴   南风 <3级     1      晴   北风 <3级    -9         详情
#       石景山    晴   南风 <3级     1      晴   北风 <3级    -8         详情
#       大兴     晴  西南风 <3级     0      晴   南风 <3级   -11         详情
#       房山     晴  西南风 <3级     0      晴   南风 <3级    -9         详情
#       密云     晴  东北风 <3级     0      晴   南风 <3级   -10         详情
#       门头沟    晴   南风 <3级     0      晴   北风 <3级    -8         详情
#       平谷     晴  西南风 <3级     0      晴   东风 <3级   -11         详情
#       东城     晴   南风 <3级     1      晴   南风 <3级    -8         详情
#       西城     晴   南风 <3级     1      晴   南风 <3级    -8         详情

# %%
url = 'https://fund.eastmoney.com/fund.html'
pd.read_html(url)[2]
# Out:
#      关注  比较   序号    基金代码                   基金简称 2024-01-05         2024-01-04  \
#      关注  比较   序号    基金代码                   基金简称       单位净值    累计净值       单位净值
# 0   NaN NaN    1    5576     华泰柏瑞新金融地产混合A估值图基金吧     1.1965  1.1965     1.1827
# 1   NaN NaN    2   16374     华泰柏瑞新金融地产混合C估值图基金吧     1.1869  1.1869     1.1732
# 2   NaN NaN    3  160631            鹏华银行A估值图基金吧     0.9150  1.0420     0.9050
# 3   NaN NaN    4   11570   鹏华鑫远价值一年持有期混合A估值图基金吧     0.7841  0.7841     0.7757
# 4   NaN NaN    5   11571   鹏华鑫远价值一年持有期混合C估值图基金吧     0.7676  0.7676     0.7595
# ..   ..  ..  ...     ...                    ...        ...     ...        ...
# 195 NaN NaN  196   12587  南方港股创新视野一年持有混合C估值图基金吧     0.8595  0.8595     0.8580
# 196 NaN NaN  197    6363  建信深证基本面60ETF联接C估值图基金吧     2.0970  2.0970     2.0937
# 197 NaN NaN  198    9849   安信稳健聚申一年持有期混合A估值图基金吧     1.1114  1.2226     1.1096
# 198 NaN NaN  199   10661   安信稳健聚申一年持有期混合C估值图基金吧     1.1057  1.2071     1.1039
# 199 NaN NaN  200    8895     申万菱信量化对冲策略混合估值图基金吧     1.0701  1.0701     1.0684
#
#                日增长值   日增长率 申购状态 赎回状态    手续费
#        累计净值    日增长值   日增长率 申购状态 赎回状态    手续费
# 0    1.1827  0.0138  1.17%   开放   开放  0.15%
# 1    1.1732  0.0137  1.17%   开放   开放  0.00%
# 2    1.0320  0.0100  1.10%   开放   开放  0.12%
# 3    0.7757  0.0084  1.08%   开放   开放  0.15%
# 4    0.7595  0.0081  1.07%   开放   开放  0.00%
# ..      ...     ...    ...  ...  ...    ...
# 195  0.8580  0.0015  0.17%   开放   开放  0.00%
# 196  2.0937  0.0033  0.16%   开放   开放  0.00%
# 197  1.2208  0.0018  0.16%  限大额   开放  1.00%
# 198  1.2053  0.0018  0.16%  限大额   开放    ---
# 199  1.0684  0.0017  0.16%   开放   开放  0.15%
#
# [200 rows x 14 columns]

# %%
dick = 'fuck'
dick
# Out:
# 'fuck'

# %%
import cv2
img = cv2.imread(r'F:\VSCode Files\Web\Notes\Statics\Image\test.png')
img.shape
# Out:
# (440, 472, 3)

# %%
m = 3
while m<10:
    n=2
    while n<=m-1:
        if m%n==0:
            break
        if n==m-1:
            print(m)
        n+=1
    m+=1
# Out:
# 3
# 5
# 7
